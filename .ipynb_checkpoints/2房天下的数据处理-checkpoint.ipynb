# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\Administrator\\Desktop\\数据分析挖掘\\部分二手房信息.csv',engine='python')

# %%
df
# Out:
#      中介         中介电话                                                 买点  产权性质  \
# 0   陈天亮  13632634126  小区名称：南海玫瑰园二期，看湾区海景，临海大社区！户型：98平米标准3房,南朝向，客厅和主卧...   商品房
# 1   郑晓娃  13613080350        1、此房是179平方的4房，户型方正，弧形窗台，采光好 2、目前是租客在用，带租约出售   商品房
# 2   陈天亮  13632634126  房子户型方正，南北通风。光线充足，房子属于框架结构，房屋可以随意改动，有人改成了5房也是很宽...   商品房
# 3   陈天亮  13632634126                           198平大五房2厅3卫，南北通透，双套房设计 ，   商品房
# 4    滕政  18689205173  蛇口【水湾1979】蛇口自贸区在卖的一手新房，现楼发售即买即住。费用只交契税。开发商保留一手...   商品房
# 5   朱盈盈  13613080580  1、此房是双玺花园的W公馆，88平方两房，正南向，采光明亮，南北通透2、新房未入住，全套智能...   商品房
# 6    滕政  18689205173  房子业主急卖 ，88㎡两房带智能家私配套。带高租约18000元。社区环境好。业主报价1080...   商品房
# 7   陈天亮  13632634126    120平复式5房带顶楼花园，南北通透，住家豪，装，近海上世界，15公里滨海长廊，明华轮太子湾中   商品房
# 8    滕政  18689205173  房子是前排别墅，206㎡，使用率达到350㎡。房子还带护院，车位。银行无欠款，一手业主，税费...   NaN
# 9   陈天亮  13632634126  南枚二期叠加别墅诚心出售 上下三层半带天台花园可以看无遮挡海景 目前毛坯买过来需要装修业主委...   NaN
# 10  童玉华  15712127758  此房为皇御苑一期花园，皇岗口岸（24通关）+福田口岸距离小区200米，真正的与香港0距离，地...   商品房
# ...

# %% [markdown]
# ## 舍弃一列

# %%
del df['Unnamed: 0']
df

# %% [markdown]
# ## 将”暂无资料” 变成缺失值

# %%
df[df['小区'] == '地图']
# Out:
#     Unnamed: 0   中介         中介电话  \
# 1            1  郑晓娃  13613080350
# 12          12  刘荣华  13424201349
#
#                                                    买点 产权性质  住宅类别  \
# 1         1、此房是179平方的4房，户型方正，弧形窗台，采光好 2、目前是租客在用，带租约出售  商品房  普通住宅
# 12  1、世金国际是不用可以直接买的，，环境好，详情咨询刘荣华134-2420-1349微信同步。...  商品房  普通住宅
#
#               区域         单价  厅结构 地下室面积 ...    房屋用途 挂牌时间 有无电梯  朝向  \
# 1    蛇口 5 套在售二手房  41899元/平米  NaN   NaN ...   商业办公类  NaN    无  暂无
# 12  蔡屋围 1 套在售二手房  48638元/平米  NaN   NaN ...   商业办公类  NaN    有   南
#
#                              标题  楼层 花园面积   装修 车位数量 车库数量
# 1   笋盘：海上世/界地/铁口物业 单价4字开头 高层海景房  高层  NaN  简装修  NaN  NaN
# 12        朝南复式 精装一楼打通 红本在手 看房方便  高层  NaN  精装修  NaN  NaN
#
# [2 rows x 28 columns]

# %%
import numpy as np
df.ix[df['小区'] == '地图', '小区'] = np.nan
df
# Out:
# c:\users\administrator\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#     Unnamed: 0   中介         中介电话  \
# 0            0  陈天亮  13632634126
# 1            1  郑晓娃  13613080350
# 2            2  陈天亮  13632634126
# 3            3  陈天亮  13632634126
# 4            4   滕政  18689205173
# 5            5  朱盈盈  13613080580
# 6            6   滕政  18689205173
# 7            7  陈天亮  13632634126
# 8            8   滕政  18689205173
# 9            9  陈天亮  13632634126
# 10          10  童玉华  15712127758
# 11          11   杨群  13554729566
# 12          12  刘荣华  13424201349
# 13          13  张钗铃  15914169985
# 14          14  邱美莲  16698202260
# 15          15  周瑶丽  13148873633
# 16          16   黄雷  18138409949
# ...

# %%
#读取文件时 就将数据处理
import pandas as pd
df = pd.read_csv('C:\\Users\\Administrator\\Desktop\\数据分析挖掘\\部分二手房信息.csv',na_values = '地图',engine='python')
del df['买点'] 
del df['Unnamed: 0']
df
# Out:
#      中介         中介电话  产权性质  住宅类别            区域          单价  厅结构  地下室面积  \
# 0   陈天亮  13632634126   商品房  普通住宅         南山 蛇口  106061元/平米  NaN    NaN
# 1   郑晓娃  13613080350   商品房  普通住宅   蛇口 5 套在售二手房   41899元/平米  NaN    NaN
# 2   陈天亮  13632634126   商品房  普通住宅         南山 蛇口   64378元/平米  NaN    NaN
# 3   陈天亮  13632634126   商品房  普通住宅         南山 蛇口  100000元/平米  NaN    NaN
# 4    滕政  18689205173   商品房  普通住宅         南山 蛇口   82031元/平米  NaN    NaN
# 5   朱盈盈  13613080580   商品房  普通住宅         南山 蛇口  130682元/平米  NaN    NaN
# 6    滕政  18689205173   商品房  高档住宅         南山 蛇口  115909元/平米  NaN    NaN
# 7   陈天亮  13632634126   商品房  普通住宅         南山 蛇口   72727元/平米  NaN    NaN
# 8    滕政  18689205173   NaN   NaN         南山 蛇口  136893元/平米   挑高  100平米
# 9   陈天亮  13632634126   NaN   NaN         南山 蛇口  160194元/平米   挑高  100平米
# 10  童玉华  15712127758   商品房   NaN         福田 皇岗   53165元/平米  NaN    NaN
# 11   杨群  13554729566  个人产权  普通住宅         罗湖 布心   58163元/平米  NaN    NaN
# ...

# %% [markdown]
# ## 检查后三行数据

# %%
df.tail(3)
# Out:
#      中介         中介电话 产权性质  住宅类别        区域         单价  厅结构 地下室面积      小区  \
# 17   赵成  15885643096  商品房  普通住宅     福田 景田  55727元/平米  NaN   NaN    时代华庭
# 18   丁一  13714402431  商品房  普通住宅     南山 蛇口  58642元/平米  NaN   NaN    南水小区
# 19  梁红英  13556837557  商品房  普通住宅  龙岗 龙岗中心城  32584元/平米  NaN   NaN  深房传麒尚林
#
#      建筑年代 ...  房屋用途        挂牌时间 有无电梯  朝向                            标题  楼层  \
# 17  2001年 ...   NaN  2018-09-13    有   南      市民旁，01年社区，楼下就是公园，业主80万装修  中层
# 18  1990年 ...   NaN  2018-08-24    无   南  2号线水湾站旁 精装大2房 花园中间 正南向 待拆迁物业  中层
# 19  2014年 ...   NaN  2018-09-19    无  东南  深房传麒尚林，真图实价，全新精装修大三房，南北通透看花园  高层
#
#    花园面积   装修 车位数量 车库数量
# 17  NaN  精装修  NaN  NaN
# 18  NaN  精装修  NaN  NaN
# 19  NaN  精装修  NaN  NaN
#
# [3 rows x 26 columns]

# %% [markdown]
# ## DataFrame 字段信息

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 26 columns):
# 中介       20 non-null object
# 中介电话     20 non-null int64
# 产权性质     17 non-null object
# 住宅类别     16 non-null object
# 区域       20 non-null object
# 单价       20 non-null object
# 厅结构      3 non-null object
# 地下室面积    2 non-null object
# 小区       18 non-null object
# 建筑年代     20 non-null object
# 建筑形式     3 non-null object
# 建筑类别     15 non-null object
# 建筑结构     16 non-null object
# 建筑面积     20 non-null object
# 总价       20 non-null object
# 户型       20 non-null object
# 房屋用途     2 non-null object
# 挂牌时间     17 non-null object
# 有无电梯     17 non-null object
# 朝向       20 non-null object
# 标题       20 non-null object
# 楼层       20 non-null object
# 花园面积     2 non-null object
# 装修       20 non-null object
# 车位数量     2 non-null float64
# 车库数量     3 non-null float64
# dtypes: float64(2), int64(1), object(23)
# memory usage: 4.1+ KB

# %% [markdown]
# ## 检查 字段名称

# %%
df.columns
# Out:
# Index(['中介', '中介电话', '产权性质', '住宅类别', '区域', '单价', '厅结构', '地下室面积', '小区', '建筑年代',
#        '建筑形式', '建筑类别', '建筑结构', '建筑面积', '总价', '户型', '房屋用途', '挂牌时间', '有无电梯',
#        '朝向', '标题', '楼层', '花园面积', '装修', '车位数量', '车库数量'],
#       dtype='object')

# %% [markdown]
# ## 检查字段信息

# %%
df.dtypes
# Out:
# 中介        object
# 中介电话       int64
# 产权性质      object
# 住宅类别      object
# 区域        object
# 单价        object
# 厅结构       object
# 地下室面积     object
# 小区        object
# 建筑年代      object
# 建筑形式      object
# 建筑类别      object
# 建筑结构      object
# 建筑面积      object
# 总价        object
# 户型        object
# 房屋用途      object
# 挂牌时间      object
# 有无电梯      object
# 朝向        object
# 标题        object
# 楼层        object
# 花园面积      object
# 装修        object
# 车位数量     float64
# 车库数量     float64
# dtype: object

# %% [markdown]
# ## 取得 叙述性统计

# %%
df.describe()
# Out:
#                中介电话  车位数量      车库数量
# count  2.000000e+01   2.0  3.000000
# mean   1.506023e+10   1.0  1.333333
# std    2.058979e+09   0.0  0.577350
# min    1.314887e+10   1.0  1.000000
# 25%    1.361308e+10   1.0  1.000000
# 50%    1.363263e+10   1.0  1.000000
# 75%    1.611018e+10   1.0  1.500000
# max    1.868921e+10   1.0  2.000000

# %% [markdown]
# ## 检查缺失值

# %%
# df.isnull()
df.isnull().any()   #缺失值的栏位
# Out:
# 中介       False
# 中介电话     False
# 产权性质      True
# 住宅类别      True
# 区域       False
# 单价       False
# 厅结构       True
# 地下室面积     True
# 小区        True
# 建筑年代     False
# 建筑形式      True
# 建筑类别      True
# 建筑结构      True
# 建筑面积     False
# 总价       False
# 户型       False
# 房屋用途      True
# 挂牌时间      True
# 有无电梯      True
# 朝向       False
# 标题       False
# 楼层       False
# 花园面积      True
# 装修       False
# 车位数量      True
# 车库数量      True
# dtype: bool

# %%
df.isnull().sum()   #缺失值数量
# Out:
# 中介        0
# 中介电话      0
# 产权性质      3
# 住宅类别      4
# 区域        0
# 单价        0
# 厅结构      17
# 地下室面积    18
# 小区        2
# 建筑年代      0
# 建筑形式     17
# 建筑类别      5
# 建筑结构      4
# 建筑面积      0
# 总价        0
# 户型        0
# 房屋用途     18
# 挂牌时间      3
# 有无电梯      3
# 朝向        0
# 标题        0
# 楼层        0
# 花园面积     18
# 装修        0
# 车位数量     18
# 车库数量     17
# dtype: int64

# %%
df.isnull().sum() / (df.count() + df.isnull().sum())   #空的数量 / 总的
# Out:
# 中介       0.00
# 中介电话     0.00
# 产权性质     0.15
# 住宅类别     0.20
# 区域       0.00
# 单价       0.00
# 厅结构      0.85
# 地下室面积    0.90
# 小区       0.10
# 建筑年代     0.00
# 建筑形式     0.85
# 建筑类别     0.25
# 建筑结构     0.20
# 建筑面积     0.00
# 总价       0.00
# 户型       0.00
# 房屋用途     0.90
# 挂牌时间     0.15
# 有无电梯     0.15
# 朝向       0.00
# 标题       0.00
# 楼层       0.00
# 花园面积     0.90
# 装修       0.00
# 车位数量     0.90
# 车库数量     0.85
# dtype: float64

# %% [markdown]
# ## 删除缺失字段

# %%
df = df.drop('房屋用途',axis=1)
df.dtypes
# Out:
# 中介        object
# 中介电话       int64
# 产权性质      object
# 住宅类别      object
# 区域        object
# 单价        object
# 厅结构       object
# 地下室面积     object
# 小区        object
# 建筑年代      object
# 建筑形式      object
# 建筑类别      object
# 建筑结构      object
# 建筑面积      object
# 总价        object
# 户型        object
# 挂牌时间      object
# 有无电梯      object
# 朝向        object
# 标题        object
# 楼层        object
# 花园面积      object
# 装修        object
# 车位数量     float64
# 车库数量     float64
# dtype: object

# %% [markdown]
# ## 筛选字段

# %%
df['装修'].value_counts()
# Out:
# 精装修     16
# 豪华装修     2
# 简装修      2
# Name: 装修, dtype: int64

# %%
df[df['装修'] == '精装修'].head(3)
# Out:
#     中介         中介电话 产权性质  住宅类别     区域          单价  厅结构 地下室面积        小区   建筑年代  \
# 0  陈天亮  13632634126  商品房  普通住宅  南山 蛇口  106061元/平米  NaN   NaN  南海玫瑰花园二期  2005年
# 2  陈天亮  13632634126  商品房  普通住宅  南山 蛇口   64378元/平米  NaN   NaN     天海豪景苑  2000年
# 3  陈天亮  13632634126  商品房  普通住宅  南山 蛇口  100000元/平米  NaN   NaN     兰溪谷二期  2007年
#
#   ...       户型        挂牌时间 有无电梯  朝向                              标题  楼层 花园面积  \
# 0 ...   3室2厅1卫  2018-09-25    有   南  户型方正，客厅宽敞，带大阳台，一进门就可以看到外面的风景，一  中层  NaN
# 2 ...   3室2厅2卫  2018-09-21    有  东南      豪气精装修,景观开阔带育/才/名/校/双/学/位/房  中层  NaN
# 3 ...   5室2厅3卫  2018-09-23    有  东南         小区总价低大宅,198平5房，两个大套房，大气  低层  NaN
#
#     装修 车位数量 车库数量
# 0  精装修  NaN  NaN
# 2  精装修  NaN  NaN
# 3  精装修  NaN  NaN
#
# [3 rows x 25 columns]

# %%
df.iloc[5:7]   #按序号筛选
# Out:
#     中介         中介电话 产权性质  住宅类别     区域          单价  厅结构 地下室面积          小区  \
# 5  朱盈盈  13613080580  商品房  普通住宅  南山 蛇口  130682元/平米  NaN   NaN  海上世界双玺花园三期
# 6   滕政  18689205173  商品房  高档住宅  南山 蛇口  115909元/平米  NaN   NaN  海上世界双玺花园三期
#
#     建筑年代 ...       户型        挂牌时间 有无电梯 朝向                         标题  楼层 花园面积  \
# 5  2018年 ...   2室1厅1卫  2018-09-29    有  南   双玺公馆 新房未入住 南向精装两房 智能家居设计  低层  NaN
# 6  2018年 ...   2室1厅1卫  2018-09-27    有  西  双玺靓房出售 价格低于市场价100万 买来就的房子  低层  NaN
#
#     装修 车位数量 车库数量
# 5  精装修  NaN  NaN
# 6  精装修  NaN  NaN
#
# [2 rows x 25 columns]

# %%
df.loc[(df['建筑面积'] == '88平米') & (df['朝向'] == '南')]   #混合筛选
# Out:
#     中介         中介电话 产权性质  住宅类别     区域          单价  厅结构 地下室面积          小区  \
# 5  朱盈盈  13613080580  商品房  普通住宅  南山 蛇口  130682元/平米  NaN   NaN  海上世界双玺花园三期
#
#     建筑年代 ...       户型        挂牌时间 有无电梯 朝向                        标题  楼层 花园面积  \
# 5  2018年 ...   2室1厅1卫  2018-09-29    有  南  双玺公馆 新房未入住 南向精装两房 智能家居设计  低层  NaN
#
#     装修 车位数量 车库数量
# 5  精装修  NaN  NaN
#
# [1 rows x 25 columns]

# %%
df = df[df['装修'] == '精装修']

# %%
df['装修'].value_counts()
# Out:
# 精装修    16
# Name: 装修, dtype: int64

# %% [markdown]
# ## 舍弃包含缺失值的字段

# %%
df.head(3)
# Out:
#     中介         中介电话 产权性质  住宅类别     区域          单价  厅结构 地下室面积        小区   建筑年代  \
# 0  陈天亮  13632634126  商品房  普通住宅  南山 蛇口  106061元/平米  NaN   NaN  南海玫瑰花园二期  2005年
# 2  陈天亮  13632634126  商品房  普通住宅  南山 蛇口   64378元/平米  NaN   NaN     天海豪景苑  2000年
# 3  陈天亮  13632634126  商品房  普通住宅  南山 蛇口  100000元/平米  NaN   NaN     兰溪谷二期  2007年
#
#   ...       户型        挂牌时间 有无电梯  朝向                              标题  楼层 花园面积  \
# 0 ...   3室2厅1卫  2018-09-25    有   南  户型方正，客厅宽敞，带大阳台，一进门就可以看到外面的风景，一  中层  NaN
# 2 ...   3室2厅2卫  2018-09-21    有  东南      豪气精装修,景观开阔带育/才/名/校/双/学/位/房  中层  NaN
# 3 ...   5室2厅3卫  2018-09-23    有  东南         小区总价低大宅,198平5房，两个大套房，大气  低层  NaN
#
#     装修 车位数量 车库数量
# 0  精装修  NaN  NaN
# 2  精装修  NaN  NaN
# 3  精装修  NaN  NaN
#
# [3 rows x 25 columns]

# %%
df.dropna(axis=1,how = 'all')

# %% [markdown]
# ## 补齐缺失值

# %%
df['车位数量'] = df['车位数量'].fillna(0)  #对nan用0来填充

# %%
df.head(3)

# %% [markdown]
# 使用 近似值补齐信息

# %%
df.isnull().sum()
# Out:
# 中介        0
# 中介电话      0
# 产权性质      2
# 住宅类别      3
# 区域        0
# 单价        0
# 厅结构      14
# 地下室面积    14
# 小区        1
# 建筑年代      0
# 建筑形式     14
# 建筑类别      4
# 建筑结构      3
# 建筑面积      0
# 总价        0
# 户型        0
# 挂牌时间      2
# 有无电梯      2
# 朝向        0
# 标题        0
# 楼层        0
# 花园面积     14
# 装修        0
# 车位数量      0
# 车库数量     14
# dtype: int64

# %%
df['产权性质']
# Out:
# 0      商品房
# 2      商品房
# 3      商品房
# 4      商品房
# 5      商品房
# 6      商品房
# 8      NaN
# 9      NaN
# 10     商品房
# 11    个人产权
# 12     商品房
# 13     商品房
# 16     商品房
# 17     商品房
# 18     商品房
# 19     商品房
# Name: 产权性质, dtype: object

# %%
df['产权性质'] = df['产权性质'].fillna('商品房')  #把最有可能的选项填充进去
df['产权性质']

# %%
df
# Out:
#      中介         中介电话  产权性质  住宅类别            区域          单价  厅结构  地下室面积  \
# 0   陈天亮  13632634126   商品房  普通住宅         南山 蛇口  106061元/平米  NaN    NaN
# 2   陈天亮  13632634126   商品房  普通住宅         南山 蛇口   64378元/平米  NaN    NaN
# 3   陈天亮  13632634126   商品房  普通住宅         南山 蛇口  100000元/平米  NaN    NaN
# 4    滕政  18689205173   商品房  普通住宅         南山 蛇口   82031元/平米  NaN    NaN
# 5   朱盈盈  13613080580   商品房  普通住宅         南山 蛇口  130682元/平米  NaN    NaN
# 6    滕政  18689205173   商品房  高档住宅         南山 蛇口  115909元/平米  NaN    NaN
# 8    滕政  18689205173   商品房   NaN         南山 蛇口  136893元/平米   挑高  100平米
# 9   陈天亮  13632634126   商品房   NaN         南山 蛇口  160194元/平米   挑高  100平米
# 10  童玉华  15712127758   商品房   NaN         福田 皇岗   53165元/平米  NaN    NaN
# 11   杨群  13554729566  个人产权  普通住宅         罗湖 布心   58163元/平米  NaN    NaN
# 12  刘荣华  13424201349   商品房  普通住宅  蔡屋围 1 套在售二手房   48638元/平米  NaN    NaN
# 13  张钗铃  15914169985   商品房  普通住宅      龙岗 龙岗中心城   47753元/平米  NaN    NaN
# ...

# %% [markdown]
# ## 自由发挥时间

# %%
del df['厅结构']

# %%
df['地下室面积'] = df['地下室面积'].fillna(0)

# %%
df['花园面积'] = df['花园面积'].fillna(0)

# %%
df['有无电梯'] = df['有无电梯'].fillna('有')

# %%
df['车库数量'] = df['车库数量'].fillna(0)

# %%
del df['建筑形式']

# %%
df
# Out:
#      中介         中介电话  产权性质  住宅类别            区域          单价  地下室面积          小区  \
# 0   陈天亮  13632634126   商品房  普通住宅         南山 蛇口  106061元/平米      0    南海玫瑰花园二期
# 2   陈天亮  13632634126   商品房  普通住宅         南山 蛇口   64378元/平米      0       天海豪景苑
# 3   陈天亮  13632634126   商品房  普通住宅         南山 蛇口  100000元/平米      0       兰溪谷二期
# 4    滕政  18689205173   商品房  普通住宅         南山 蛇口   82031元/平米      0      水湾1979
# 5   朱盈盈  13613080580   商品房  普通住宅         南山 蛇口  130682元/平米      0  海上世界双玺花园三期
# 6    滕政  18689205173   商品房  高档住宅         南山 蛇口  115909元/平米      0  海上世界双玺花园三期
# 8    滕政  18689205173   商品房   NaN         南山 蛇口  136893元/平米  100平米  南海玫瑰花园二期别墅
# 9   陈天亮  13632634126   商品房   NaN         南山 蛇口  160194元/平米  100平米  南海玫瑰花园二期别墅
# 10  童玉华  15712127758   商品房   NaN         福田 皇岗   53165元/平米      0         皇御苑
# 11   杨群  13554729566  个人产权  普通住宅         罗湖 布心   58163元/平米      0       彩世界家园
# 12  刘荣华  13424201349   商品房  普通住宅  蔡屋围 1 套在售二手房   48638元/平米      0         NaN
# ...

# %% [markdown]
# ## 处理后的数据

# %%
df.to_csv('C:\\Users\\Administrator\\Desktop\\数据分析挖掘\\处理过的数据.csv')  #不要索引 ,index_label=False
